# %% [markdown]
# # Hipótesis:
# Premisa: ver las actividades relacionadas con numero de ataques
#
# Los ataques que más acaban en muerte son los de los surfistasa
#
# En australia hay más ataques que en el resto del mundo porque el agua está más caliente, sobre todo en diciembre porque hay más turistas en navidad
#
# tiburones2.yearnuevo.fillna(1700, inplace=True)
# tiburones2.yearnuevo.fillna(1700, inplace=True)

# %%
#importamos librerías
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import src.funciones_limpiar as fl

# %%
# Matplotlib inline para visualizar los gráficos de Matplotlib
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'

# %%
# Configuración para setear y que todas las fig de Seaborn salgan por defecto con este tamaño
# Se puede especificar el tamaño de cada figura
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %%
import sys
# !conda install --yes --prefix {sys.prefix} plotly
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/mariadelas/anaconda3/envs/ironhack
#
#   added / updated specs:
#     - plotly
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.10.26 |       h06a4308_2         115 KB
#     plotly-5.1.0               |     pyhd3eb1b0_0         2.7 MB
#     tenacity-8.0.1             |   py38h06a4308_0          38 KB
#     ------------------------------------------------------------
#                                            Total:         2.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   plotly             pkgs/main/noarch::plotly-5.1.0-pyhd3eb1b0_0
# ...

# %%
df = pd.read_csv("data/countries.csv",encoding = "ISO-8859-1")

# %%
df
# Out:
#       Unnamed: 0    casenumber         Date          Type       Country  \
# 0              2    2018.06.09  09-Jun-2018  Questionable           USA
# 1              3    2018.06.08  08-Jun-2018    Unprovoked     AUSTRALIA
# 2              7    2018.05.27  27-May-2018    Unprovoked           USA
# 3             12  2018.05.13.b  13-May-2018    Unprovoked           USA
# 4             15    2018.05.12  12-May-2018    Unprovoked  SOUTH AFRICA
# ...          ...           ...          ...           ...           ...
# 2047        6293       ND.0009  Before 1906    Unprovoked     AUSTRALIA
# 2048        6294       ND.0008  Before 1906    Unprovoked     AUSTRALIA
# 2049        6295       ND.0007  Before 1906    Unprovoked     AUSTRALIA
# 2050        6296       ND.0006  Before 1906    Unprovoked     AUSTRALIA
# 2051        6299       ND.0003    1900-1905    Unprovoked           USA
#
#       Activity Fatal (Y/N)                                            Species  \
# ...

# %%
sns.countplot(x="Type",data = df);

# %%
sns.countplot(x="Activity", hue="Fatal (Y/N)", data = df);

# %% [markdown]
# Refutamos nuestra hipótesis, ya que el surf no es la máxima causa de muerte, si no el nadar

# %%
sns.countplot(x="Country nuevo", data = df);

# %%
sns.catplot(x="Country nuevo", y="mes2", data=df)
plt.xticks(rotation=45);

# %%
sns.pairplot(df)

# %%
sns.histplot(x="yearnuevo", hue="Fatal (Y/N)", data=df);
