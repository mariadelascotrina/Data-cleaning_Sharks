# %% [markdown]
# # Hipótesis:
#
#
# 0. Los  los ataques que se han provocado más, han sido pescando
#
# 1. Los ataques que más acaban en muerte son los de los surfistasa
#
# 2. En australia hay más ataques que en el resto del mundo porque el agua está más caliente, sobre todo en diciembre porque hay más turistas en navidad
#
# tiburones2.yearnuevo.fillna(1700, inplace=True)
# tiburones2.yearnuevo.fillna(1700, inplace=True)

# %%
#importamos librerías
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt


import src.funciones_limpiar as fl

# %%
# Matplotlib inline para visualizar los gráficos de Matplotlib
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'

# %%
# Configuración para setear y que todas las fig de Seaborn salgan por defecto con este tamaño
# Se puede especificar el tamaño de cada figura
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %%
import sys
# !conda install --yes --prefix {sys.prefix} plotly
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
import plotly.express as px
import plotly.io as pio

# %%
pip install --upgrade nbformat
# Out:
# Requirement already up-to-date: nbformat in /home/mariadelas/anaconda3/envs/ironhack/lib/python3.8/site-packages (5.1.3)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("data/countries.csv",encoding = "ISO-8859-1")

# %%
df
# Out:
#       Unnamed: 0    casenumber         Date          Type       Country  \
# 0              2    2018.06.09  09-Jun-2018  Questionable           USA
# 1              3    2018.06.08  08-Jun-2018    Unprovoked     AUSTRALIA
# 2              7    2018.05.27  27-May-2018    Unprovoked           USA
# 3             12  2018.05.13.b  13-May-2018    Unprovoked           USA
# 4             15    2018.05.12  12-May-2018    Unprovoked  SOUTH AFRICA
# ...          ...           ...          ...           ...           ...
# 2047        6293       ND.0009  Before 1906    Unprovoked     AUSTRALIA
# 2048        6294       ND.0008  Before 1906    Unprovoked     AUSTRALIA
# 2049        6295       ND.0007  Before 1906    Unprovoked     AUSTRALIA
# 2050        6296       ND.0006  Before 1906    Unprovoked     AUSTRALIA
# 2051        6299       ND.0003    1900-1905    Unprovoked           USA
#
#       Activity Fatal (Y/N)                                            Species  \
# ...

# %%
sns.countplot(x="Activity", hue="Type", data = df, palette = 'Paired');

# %% [markdown]
# # Confirmamos hipótesis 0: los  los ataques que se han provocado más, han sido mediante la pesca (iban a pescar y les atacó el bichín)

# %%
sns.countplot(x="Activity", hue="Fatal (Y/N)", data = df, palette = "pastel");

# %% [markdown]
# # Refutamos nuestra hipótesis 1, ya que el surf no es la máxima causa de muerte, si no el nadar

# %%
sns.countplot(x="Country nuevo", data = df, palette = 'cubehelix');

# %% [markdown]
# # Refutamos nuestra hipótesis 2, ya que australia no es el país con más ataques si no USA

# %%
sns.catplot(x="Country nuevo", y="mes2", data=df, palette = 'colorblind')
plt.xticks(rotation=45); #hacemos este gráfico para ver si en diciembre es cuando más ataques hay en australia, pero no es así

# %% [markdown]
# Hemos refutado nuestras hipótesis, pero queremos seguir investigando

# %%
graf = sns.histplot(x=df.yearnuevo, bins=30, kde=True, fill='#fd7e14');
graf.axvline(x=df.yearnuevo.mean(), c="red", label="mean")
graf.axvline(x=df.yearnuevo.median(), c="black", label="median")

# %%
#¿cada vez hay más ataques o se registran más?

# %%
sns.histplot(data=df, x="yearnuevo",hue="Fatal (Y/N)", multiple="stack", bins =10, palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='yearnuevo', ylabel='Count'>

# %%
fig = px.scatter(df, x="Country nuevo", y="yearnuevo")
fig.show()
# Out:
# <div>                            <div id="ae311d59-5d74-46e4-a84d-7d30062c85b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae311d59-5d74-46e4-a84d-7d30062c85b4")) {                    Plotly.newPlot(                        "ae311d59-5d74-46e4-a84d-7d30062c85b4",                        [{"hovertemplate":"Country nuevo=%{x}<br>yearnuevo=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"type":"scattergl","x":["USA","AUSTRALIA","USA","USA","SOUTH AFRICA","AUSTRALIA","AUSTRALIA","AUSTRALIA","AUSTRALIA","AUSTRALIA","AUSTRALIA","AUSTRALIA","SOUTH AFRICA","AUSTRALIA","AUSTRALIA","AUSTRALIA","AUSTRALIA","AUSTRALIA","AUSTRALIA","USA","USA","USA","USA","AUSTRALIA","AUSTRALIA
# ...
